# %% [markdown]
# To perform Min-Max scaling on the dataset [1, 5, 10, 15, 20] and transform the values to a range of -1 to 1, we need to adjust the standard Min-Max scaling formula. The standard formula scales values to a range of 0 to 1. We can modify this formula to fit the -1 to 1 range.
#
# The modified formula for scaling a value
#
# x is:
#
# Scaled
#
#
# =
# 2
# ×
# (
#
# −
# min
# (
#
# )
# max
# (
#
# )
# −
# min
# (
#
# )
# )
# −
# 1
# Scaledx=2×(
# max(x)−min(x)
# x−min(x)
#
#  )−1
#
# In this dataset,
# min
# (
#
# )
# =
# 1
# min(x)=1 and
# max
# (
#
# )
# =
# 20
# max(x)=20. Applying the formula to each value in the dataset:
#
# For
#
#
# 1
# x=1:
# Scaled
#
# 1
# =
# 2
# ×
# (
# 1
# −
# 1
# 20
# −
# 1
# )
# −
# 1
# =
# 2
# ×
# 0
# −
# 1
# =
# −
# 1
# Scaled1=2×(
# 20−1
# 1−1
#
#  )−1=2×0−1=−1
#
# For
#
# =
# 5
# x=5:
# Scaled
#
# 5
# =
# 2
# ×
# (
# 5
# −
# 1
# 20
# −
# 1
# )
# −
# 1
# =
# 2
# ×
# (
# 4
# 19
# )
# −
# 1
# ≈
# −
# 0.579
# Scaled5=2×(
# 20−1
# 5−1
#
#  )−1=2×(
# 19
# 4
#
#  )−1≈−0.579
#
# For
#
# =
# 10
# x=10:
# Scaled
#
#
# =
# 2
# ×
# (
# 10
# −
# 1
# 20
# −
# 1
# )
# −
#
# =
# 2
# ×
# (
# 9
# 19
# )
# −
# 1
# ≈
# −
# 0.053
# Scaled10=2×(
# 20−1
# 10−1
#
#  )−1=2×(
# 19
# 9
#
#  )−1≈−0.053
#
# For
#
# =
# 15
# x=15:
# Scaled
#  15
#
# =
# 2
# ×
# (
# 15
# −
# 1
# 20
# −
# 1
# )
# −
#
# =
# 2
# ×
# (
# 14
# 19
# )
# −
# 1
# ≈
# 0.474
# Scaled15=2×(
# 20−1
# 15−1
#
#  )−1=2×(
# 19
# 14
#
#  )−1≈0.474
#
# For
#
# =
# 20
# x=20:
# Scaled
#
# 20
# =
# 2
# ×
# (
# 20
# −
# 1
# 20
# −
# 1
# )
# −
# 1
# =
# 2
# ×
# 1
# −
# 1
# =
# 1
# Scaled20=2×(
# 20−1
# 20−1
#
#  )−1=2×1−1=1
#
# So, the transformed dataset is approximately:
# [
# −
# 1
# ,
# −
# 0.579
# ,
# −
# 0.053
# ,
# 0.474
# ,
# 1
# ]
# [−1,−0.579,−0.053,0.474,1].
